# %%
import pandas as pd
import numpy as np
import scipy as st
import matplotlib.pyplot as plt

# %%
csv_path1 = "source_data/Road_Casualties_1.csv"
csv_path2 = "source_data/Road_Casualties_2.csv"

# %%
casualties1 = pd.read_csv(csv_path1)
casualties2 = pd.read_csv(csv_path2)

# %%
casualties1_df = pd.DataFrame(casualties1)
casualties1_df
# Out:
#       Accident year Casualty severity Casualty sex  Casualty age  \
# 0            2017.0            Killed         Male           1.0
# 1            2017.0            Killed         Male           2.0
# 2            2017.0            Killed         Male           3.0
# 3            2017.0            Killed         Male           4.0
# 4            2017.0            Killed         Male           5.0
# ...             ...               ...          ...           ...
# 2887         2021.0            Killed       Female          93.0
# 2888         2021.0            Killed       Female          93.0
# 2889         2021.0            Killed       Female          94.0
# 2890         2021.0            Killed       Female          97.0
# 2891            NaN               NaN          NaN           NaN
#
#                Road type     Weather condition  Casualties  Unnamed: 7
# 0       Dual carriageway    Fine no high winds         1.0         NaN
# 1     Single carriageway    Fine no high winds         1.0         NaN
# 2     Single carriageway    Fine no high winds         1.0         NaN
# 3     Single carriageway    Fine no high winds         2.0         NaN
# 4     Single carriageway    Fine no high winds         2.0         NaN
# ...                  ...                   ...         ...         ...
# 2887    Dual carriageway  Raining + high winds         1.0         NaN
# 2888  Single carriageway    Fine no high winds         1.0         NaN
# 2889  Single carriageway    Fine no high winds         1.0         NaN
# 2890    Dual carriageway    Fine no high winds         1.0         NaN
# 2891                 NaN                   NaN         NaN         NaN
#
# [2892 rows x 8 columns]

# %%
casualties2_df = pd.DataFrame(casualties2)
casualties2_df
# Out:
#       Accident year Casualty severity      Road user Speed limit  \
# 0            2017.0            Killed     Pedestrian    1-20 mph
# 1            2017.0            Killed     Pedestrian    1-20 mph
# 2            2017.0            Killed     Pedestrian    1-20 mph
# 3            2017.0            Killed     Pedestrian    1-20 mph
# 4            2017.0            Killed     Pedestrian    1-20 mph
# ...             ...               ...            ...         ...
# 6109         2021.0            Killed  Other vehicle   51-60 mph
# 6110         2021.0            Killed  Other vehicle   51-60 mph
# 6111         2021.0            Killed  Other vehicle   51-60 mph
# 6112         2021.0            Killed  Other vehicle   51-60 mph
# 6113            NaN               NaN            NaN         NaN
#
#      Accident month  Accident hour  Casualties  Unnamed: 7
# 0           January           14.0         1.0         NaN
# 1           January           21.0         1.0         NaN
# 2             March           12.0         1.0         NaN
# 3             March           22.0         1.0         NaN
# 4             April            2.0         1.0         NaN
# ...             ...            ...         ...         ...
# 6109            May           11.0         1.0         NaN
# 6110           July           10.0         1.0         NaN
# 6111      September           21.0         1.0         NaN
# 6112       November           10.0         1.0         NaN
# 6113            NaN            NaN         NaN         NaN
#
# [6114 rows x 8 columns]
